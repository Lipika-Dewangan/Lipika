# %%
import tensorflow.keras as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
mnist=tf.datasets.mnist
(xtrain,ytrain),(xtest,ytest)=mnist.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
len(xtrain)
# Out:
# 60000

# %%
len(ytrain)
# Out:
# 60000

# %%
len(xtest)
# Out:
# 10000

# %%
len(ytest)
# Out:
# 10000

# %%
plt.imshow(xtrain[0],cmap='gray')

# %%
plt.imshow(xtrain[1],cmap='gray')

# %%
for x in range(10):
  plt.imshow(xtrain[x],cmap='gray')
  plt.show()

# %%
ytrain[0]
# Out:
# 5

# %%
ytrain[1]
# Out:
# 0

# %%
ytrain[59999]
# Out:
# 8

# %%
plt.figure(figsize=(20,20))
for i in range(50):
  plt.subplot(10,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.xlabel("Label "+str(ytrain[i]),fontsize=15)
  plt.imshow(xtrain[i],cmap="gray")
plt.show()

# %%
model=tf.models.Sequential()
model.add(tf.layers.Flatten())
model.add(tf.layers.Dense(784,activation="relu"))
model.add(tf.layers.Dense(10,activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=['accuracy'])

# %%
xtrain_scaled=xtrain/255
ytrain_scaled=ytrain/255

# %%
history=model.fit(xtrain_scaled,ytrain,epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0778 - accuracy: 0.9763
# Epoch 2/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0506 - accuracy: 0.9845
# Epoch 3/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0361 - accuracy: 0.9886
# Epoch 4/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0264 - accuracy: 0.9918
# Epoch 5/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0204 - accuracy: 0.9941
# Epoch 6/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 7/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0119 - accuracy: 0.9966
# Epoch 8/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0105 - accuracy: 0.9965
# Epoch 9/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0090 - accuracy: 0.9971
# Epoch 10/15
# ...
